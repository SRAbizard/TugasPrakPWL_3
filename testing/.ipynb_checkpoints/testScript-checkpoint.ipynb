# %%
pip install selenium
# Out:
# ...
#   Using cached selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# ...

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
import time

EMAIL_ID = "saidrizkyabizard@gmail.com"

browser = Chrome("C:/Users/saidr/Downloads/Programs/chromedriver_win32/chromedriver.exe")
browser.get('https://prak3selenium.herokuapp.com/')
print(browser.title)

#Case 1: Nama kosong
browser.find_element_by_name("firstName").send_keys("")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("saidrizkyabizard@gmail.com")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("@Itera26")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("@Itera26")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
#Menambahkan isi field name yang ksosong
browser.find_element_by_name("firstName").send_keys("Said Rizky Abizard")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#Case 2: Email tidak sesuai aturan
browser.find_element_by_name("firstName").send_keys("Said Rizky Abizard")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("saidrizkyabizard")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("@Itera26")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("@Itera26")
time.sleep(2)
#Memperbaiki penulisan email dengan menambahkan kata "@gmail.com"
browser.find_element_by_name("userEmail").send_keys("@gmail.com")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#Case 3: Field password tidak sesuai aturan
browser.find_element_by_name("firstName").send_keys("Said Rizky Abizard")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("saidrizkyabizard@gmail.com")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("itera")
time.sleep(2)
#Memblok semua teks yang telah diketik dalam field
browser.find_element_by_name("userPassword").send_keys(Keys.CONTROL + "a")
time.sleep(2)
#Memencet tombol delete pada keyboard
browser.find_element_by_name("userPassword").send_keys(Keys.DELETE)
time.sleep(2)
#Menulis kembali field dengan isi yang benar
browser.find_element_by_name("userPassword").send_keys("@Itera26")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("@Itera26")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#Case 4: Field re-password tidak cocok
browser.find_element_by_name("firstName").send_keys("Said Rizky Abizard")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("saidrizkyabizard@gmail.com")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("@Itera26")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("Itera26")
time.sleep(2)
#Memblok semua teks yang telah diketik dalam field
browser.find_element_by_name("confirmPassword").send_keys(Keys.CONTROL + "a")
time.sleep(2)
#Memencet tombol delete pada keyboard
browser.find_element_by_name("confirmPassword").send_keys(Keys.DELETE)
time.sleep(2)
#Menulis kembali field dengan isi yang benar
browser.find_element_by_name("confirmPassword").send_keys("@Itera26")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#Case 5: Semua field lengkap
browser.find_element_by_name("firstName").send_keys("Said Rizky Abizard")
time.sleep(2)
browser.find_element_by_name("userEmail").send_keys("saidrizkyabizard@gmail.com")
time.sleep(2)
browser.find_element_by_name("userPassword").send_keys("@Itera26")
time.sleep(2)
browser.find_element_by_name("confirmPassword").send_keys("@Itera26")
time.sleep(2)
button = browser.find_element_by_tag_name('button')
button.click()
alert_obj = browser.switch_to.alert
time.sleep(2)
alert_obj.accept () 
time.sleep(2)
browser.refresh()

#Case 6: Semua field kosong
button = browser.find_element_by_tag_name('button')
button.click()
time.sleep(2)
browser.refresh()
# Out:
# React App
